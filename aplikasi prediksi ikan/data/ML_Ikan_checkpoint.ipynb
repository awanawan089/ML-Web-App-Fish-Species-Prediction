# %%
import pandas as pd
import numpy as np
from sklearn import model_selection
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression

# %%
df = pd.read_csv('ikan.csv')

# %%
df.head()
# Out:
#    panjang_tubuh  lebar_tubuh  panjang_sirip  lebar_sirip    spesies
# 0            5.1          3.5            1.4          0.2  Ikan Nila
# 1            4.9          3.0            1.4          0.2  Ikan Nila
# 2            4.7          3.2            1.3          0.2  Ikan Nila
# 3            4.6          3.1            1.5          0.2  Ikan Nila
# 4            5.0          3.6            1.4          0.2  Ikan Nila

# %%
df.describe()
# Out:
#        panjang_tubuh  lebar_tubuh  panjang_sirip  lebar_sirip
# count     150.000000   150.000000     150.000000   150.000000
# mean        5.843333     3.054000       3.758667     1.198667
# std         0.828066     0.433594       1.764420     0.763161
# min         4.300000     2.000000       1.000000     0.100000
# 25%         5.100000     2.800000       1.600000     0.300000
# 50%         5.800000     3.000000       4.350000     1.300000
# 75%         6.400000     3.300000       5.100000     1.800000
# max         7.900000     4.400000       6.900000     2.500000

# %%
df.isna().sum()
# Out:
# panjang_tubuh    0
# lebar_tubuh      0
# panjang_sirip    0
# lebar_sirip      0
# spesies          0
# dtype: int64

# %%
df.shape
# Out:
# (150, 5)

# %%
print(df.groupby('spesies').size())
# Out:
# spesies
# Ikan Lele    50
# Ikan Mas     50
# Ikan Nila    50
# dtype: int64

# %%
array = df.values
X = array[:,0:4]
Y = array[:,4]

# %%
validation_size = 0.20
seed = 7
X_train, X_validation, Y_train, Y_validation = model_selection.train_test_split(
    X, Y, test_size=validation_size, random_state=seed
)

# %%
from sklearn.linear_model import LogisticRegression
logit = LogisticRegression()

# %%
logit.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
print('accuracy :', logit.score(X_validation,Y_validation))
# Out:
# accuracy : 0.8666666666666667

# %%
logit.predict(X_validation)
# Out:
# array(['Ikan Lele', 'Ikan Mas', 'Ikan Nila', 'Ikan Mas', 'Ikan Mas',
#        'Ikan Nila', 'Ikan Mas', 'Ikan Mas', 'Ikan Nila', 'Ikan Mas',
#        'Ikan Lele', 'Ikan Mas', 'Ikan Nila', 'Ikan Lele', 'Ikan Nila',
#        'Ikan Lele', 'Ikan Lele', 'Ikan Lele', 'Ikan Nila', 'Ikan Nila',
#        'Ikan Mas', 'Ikan Lele', 'Ikan Mas', 'Ikan Mas', 'Ikan Lele',
#        'Ikan Lele', 'Ikan Mas', 'Ikan Mas', 'Ikan Lele', 'Ikan Lele'],
#       dtype=object)

# %%
mysample = np.array([4.9,3.0,1.4,0.2])
ex1 = mysample.reshape(1,-1)

# %%
ex1
# Out:
# array([[4.9, 3. , 1.4, 0.2]])

# %%
logit.predict(ex1)
# Out:
# array(['Ikan Nila'], dtype=object)

# %%
import joblib

# %%
joblib.dump(logit, 'logit_model.pkl')
# Out:
# ['logit_model.pkl']

# %%
logit_model = joblib.load('logit_model.pkl')

# %%
df.tail()
# Out:
#      panjang_tubuh  lebar_tubuh  panjang_sirip  lebar_sirip    spesies
# 145            6.7          3.0            5.2          2.3  Ikan Lele
# 146            6.3          2.5            5.0          1.9  Ikan Lele
# 147            6.5          3.0            5.2          2.0  Ikan Lele
# 148            6.2          3.4            5.4          2.3  Ikan Lele
# 149            5.9          3.0            5.1          1.8  Ikan Lele

# %%
ex2 = np.array([6.2,3.4,5.4,2.3]).reshape(1,-1)

# %%
logit_model.predict(ex2)
# Out:
# array(['Ikan Lele'], dtype=object)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC

# %%
knn = KNeighborsClassifier()
dtree = DecisionTreeClassifier()
svm = SVC()

# %%
knn.fit(X_train,Y_train)
print('accuracy :', knn.score(X_validation,Y_validation))
# Out:
# accuracy : 0.9

# %%
joblib.dump(knn, 'knn_iris.pkl')
# Out:
# ['knn_iris.pkl']

# %%
dtree.fit(X_train,Y_train)
print('accuracy :', dtree.score(X_validation,Y_validation))
# Out:
# accuracy : 0.9

# %%
joblib.dump(dtree, 'dtree_iris.pkl')
# Out:
# ['dtree_iris.pkl']

# %%
svm.fit(X_train,Y_train)
print('accuracy :', svm.score(X_validation,Y_validation))
# Out:
# accuracy : 0.8666666666666667

# %%
joblib.dump(svm, 'svm_iris.pkl')
# Out:
# ['svm_iris.pkl']
